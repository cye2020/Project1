# %% [markdown]
# ## 필요한 라이브러리 임포트

# %%
# 표준 라이브러리 임포트

# 서드 파티 라이브러리 임포트
import pandas as pd

# 로컬 모듈 임포트
from config import DATA_DIR
from utils import load_dataset

# %% [markdown]
# ## Detroit의  최근 5시즌 승률 그래프 그리기

# %% [markdown]
# ### Detroit 시즌 별 최종 승률 데이터 준비

# %%
# 데이터셋 불러오기
ranking = load_dataset('ranking')
ranking.head(10)
# Out:
#       TEAM_ID  LEAGUE_ID SEASON_ID STANDINGSDATE CONFERENCE         TEAM   G  \
# 0  1610612743          0     22022    2022-12-22       West       Denver  30
# 1  1610612763          0     22022    2022-12-22       West      Memphis  30
# 2  1610612740          0     22022    2022-12-22       West  New Orleans  31
# 3  1610612756          0     22022    2022-12-22       West      Phoenix  32
# 4  1610612746          0     22022    2022-12-22       West  LA Clippers  33
# 5  1610612758          0     22022    2022-12-22       West   Sacramento  30
# 6  1610612762          0     22022    2022-12-22       West         Utah  35
# 7  1610612757          0     22022    2022-12-22       West     Portland  32
# 8  1610612742          0     22022    2022-12-22       West       Dallas  32
# 9  1610612750          0     22022    2022-12-22       West    Minnesota  32
#
#     W   L  W_PCT HOME_RECORD ROAD_RECORD  RETURNTOPLAY
# 0  19  11  0.633        10-3         9-8           NaN
# 1  19  11  0.633        13-2         6-9           NaN
# 2  19  12  0.613        13-4         6-8           NaN
# 3  19  13  0.594        14-4         5-9           NaN
# 4  19  14  0.576        11-7         8-7           NaN
# 5  17  13  0.567         9-5         8-8           NaN
# 6  19  16  0.543        12-5        7-11           NaN
# 7  17  15  0.531         7-6        10-9           NaN
# 8  16  16  0.500        12-5        4-11           NaN
# 9  16  16  0.500         9-8         7-8           NaN

# %%
# Detroit의 ranking만 가져오기
team_cond = ranking['TEAM'] == 'Detroit'
detroit_ranking =ranking[team_cond]

# 각 시즌 별 최종 랭킹
last_date = detroit_ranking.groupby('SEASON_ID').agg({'STANDINGSDATE': 'max'})
final_cond = detroit_ranking['STANDINGSDATE'].isin(last_date['STANDINGSDATE'])
final_detroit_ranking = detroit_ranking[final_cond].sort_values('STANDINGSDATE')
final_detroit_ranking.head(10)
# Out:
#            TEAM_ID  LEAGUE_ID SEASON_ID STANDINGSDATE CONFERENCE     TEAM   G  \
# 181497  1610612765          0     22002    2003-10-04       East  Detroit  82
# 181156  1610612765          0     12003    2003-10-27       East  Detroit   0
# 175903  1610612765          0     22003    2004-10-11       East  Detroit  82
# 175592  1610612765          0     12004    2004-11-01       East  Detroit   0
# 170458  1610612765          0     22004    2005-10-09       East  Detroit  82
# 170131  1610612765          0     12005    2005-10-31       East  Detroit   8
# 165057  1610612765          0     22005    2006-10-04       East  Detroit  82
# 164672  1610612765          0     12006    2006-10-30       East  Detroit   8
# 159567  1610612765          0     22006    2007-10-05       East  Detroit  82
# 159215  1610612765          0     12007    2007-10-29       East  Detroit   8
#
#          W   L  W_PCT HOME_RECORD ROAD_RECORD  RETURNTOPLAY
# 181497  50  32  0.610       30-11       20-21           NaN
# 181156   0   0  0.000         0-0         0-0           NaN
# 175903  54  28  0.659       31-10       23-18           NaN
# 175592   0   0  0.000         0-0         0-0           NaN
# 170458  54  28  0.659        32-9       22-19           NaN
# 170131   4   4  0.500         4-1         0-3           NaN
# 165057  64  18  0.780        37-4       27-14           NaN
# 164672   5   3  0.625         3-2         2-1           NaN
# 159567  53  29  0.646       26-15       27-14           NaN
# 159215   4   4  0.500         4-1         0-3           NaN

# %% [markdown]
# ### 필요한 시각화 라이브러리 임포트

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['font.family'] = 'NanumGothic'
# %matplotlib inline

# %% [markdown]
# ### 꺾은선 그래프로 시각화

# %%
# 파생 변수 생성
final_detroit_ranking['SEASON_FLAG'] = final_detroit_ranking['SEASON_ID'].apply(lambda id: id[0])
final_detroit_ranking['YEAR'] = final_detroit_ranking['SEASON_ID'].apply(lambda id: id[1:])

# %%
plt.figure(figsize=(10, 4))
sns.lineplot(final_detroit_ranking.iloc[-20:], x='YEAR', y='W_PCT', hue='SEASON_FLAG')

plt.title('Detroit의 시즌 별 승률')
plt.xlabel('시즌')
plt.ylabel('승률')
plt.ylim((0, 1))
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [raw]
# 과제: 프리시즌을 나가지 않은 (승률이 0인) 케이스를 어떻게 처리할 것인가

# %% [markdown]
# ## 최근 5년 순위 그래프 그리기

# %% [markdown]
# ## 시즌별 순위 파생 변수 생성

# %%
team = 'L.A. Lakers'

# %%
last_date = ranking.groupby('SEASON_ID').agg({'STANDINGSDATE': 'max'})
last_date_cond = ranking['STANDINGSDATE'].isin(last_date['STANDINGSDATE'])
final_ranking = ranking[last_date_cond].copy()
final_ranking['SEASON_RANK'] = final_ranking.groupby('SEASON_ID')['W_PCT'].rank(method='min', ascending=False)

final_ranking.sort_values(by=['STANDINGSDATE', 'SEASON_RANK'])
# Out:
#           TEAM_ID  LEAGUE_ID SEASON_ID STANDINGSDATE CONFERENCE         TEAM  \
# 92896  1610612742          0     22002    2003-10-04       West       Dallas
# 92897  1610612759          0     22002    2003-10-04       West  San Antonio
# 92898  1610612758          0     22002    2003-10-04       West   Sacramento
# 92899  1610612750          0     22002    2003-10-04       West    Minnesota
# 92900  1610612747          0     22002    2003-10-04       West  L.A. Lakers
# ...           ...        ...       ...           ...        ...          ...
# 4287   1610612764          0     22022    2022-12-22       East   Washington
# 13     1610612759          0     22022    2022-12-22       West  San Antonio
# 14     1610612745          0     22022    2022-12-22       West      Houston
# 4288   1610612766          0     22022    2022-12-22       East    Charlotte
# 4289   1610612765          0     22022    2022-12-22       East      Detroit
#
#         G   W   L  W_PCT HOME_RECORD ROAD_RECORD  RETURNTOPLAY  SEASON_RANK
# 92896  82  60  22  0.732        33-8       27-14           NaN          1.0
# 92897  82  60  22  0.732        33-8       27-14           NaN          1.0
# 92898  82  59  23  0.720        35-6       24-17           NaN          3.0
# 92899  82  51  31  0.622        33-8       18-23           NaN          4.0
# 92900  82  50  32  0.610       31-10       19-22           NaN          5.0
# ...    ..  ..  ..    ...         ...         ...           ...          ...
# 4287   33  12  21  0.364         8-7        4-14           NaN         25.0
# 13     31  10  21  0.323        5-12         5-9           NaN         27.0
# 14     31   9  22  0.290         6-9        3-13           NaN         28.0
# 4288   32   8  24  0.250        4-11        4-13           NaN         29.0
# 4289   34   8  26  0.235        4-12        4-14           NaN         30.0
#
# [1230 rows x 14 columns]

# %% [markdown]
# ### 순위 그래프 그리기

# %%
# 파생 변수 생성
final_ranking['SEASON_FLAG'] = final_ranking['SEASON_ID'].apply(lambda id: id[0])
final_ranking['YEAR'] = final_ranking['SEASON_ID'].apply(lambda id: id[1:])

# %%
detroit_season_ranking = final_ranking[final_ranking['TEAM'] == team].sort_values('STANDINGSDATE')
detroit_season_ranking
# Out:
#            TEAM_ID  LEAGUE_ID SEASON_ID STANDINGSDATE CONFERENCE         TEAM  \
# 92900   1610612747          0     22002    2003-10-04       West  L.A. Lakers
# 92579   1610612747          0     12003    2003-10-27       West  L.A. Lakers
# 87676   1610612747          0     22003    2004-10-11       West  L.A. Lakers
# 87364   1610612747          0     12004    2004-11-01       West  L.A. Lakers
# 82240   1610612747          0     22004    2005-10-09       West  L.A. Lakers
# 81902   1610612747          0     12005    2005-10-31       West  L.A. Lakers
# 76834   1610612747          0     22005    2006-10-04       West  L.A. Lakers
# 76446   1610612747          0     12006    2006-10-30       West  L.A. Lakers
# 71346   1610612747          0     22006    2007-10-05       West  L.A. Lakers
# 70991   1610612747          0     12007    2007-10-29       West  L.A. Lakers
# 65864   1610612747          0     22007    2008-10-04       West  L.A. Lakers
# 65521   1610612747          0     12008    2008-10-27       West  L.A. Lakers
# 60449   1610612747          0     22008    2009-09-30       West  L.A. Lakers
# 60060   1610612747          0     12009    2009-10-26       West  L.A. Lakers
# 54944   1610612747          0     22009    2010-10-02       West  L.A. Lakers
# 54607   1610612747          0     12010    2010-10-25       West  L.A. Lakers
# 48361   1610612747          0     22010    2011-12-15       West  L.A. Lakers
# 48236   1610612747          0     12011    2011-12-24       West  L.A. Lakers
# 43951   1610612747          0     22011    2012-10-04       West  L.A. Lakers
# 43588   1610612747          0     12012    2012-10-29       West  L.A. Lakers
# 38481   1610612747          0     22012    2013-10-04       West  L.A. Lakers
# 38123   1610612747          0     12013    2013-10-28       West  L.A. Lakers
# 121255  1610612747          0     22013    2014-10-03       West  L.A. Lakers
# 120891  1610612747          0     12014    2014-10-27       West  L.A. Lakers
# 115810  1610612747          0     22014    2015-10-01       West  L.A. Lakers
# 115433  1610612747          0     12015    2015-10-26       West  L.A. Lakers
# 110336  1610612747          0     22015    2016-09-30       West  L.A. Lakers
# 109975  1610612747          0     12016    2016-10-24       West  L.A. Lakers
# 104875  1610612747          0     22016    2017-09-29       West  L.A. Lakers
# 104619  1610612747          0     12017    2017-10-16       West  L.A. Lakers
# 99427   1610612747          0     22017    2018-09-27       West  L.A. Lakers
# 99154   1610612747          0     12018    2018-10-15       West  L.A. Lakers
# 93921   1610612747          0     22018    2019-09-29       West  L.A. Lakers
# 24168   1610612747          0     12019    2020-07-29       West  L.A. Lakers
# 22154   1610612747          0     22019    2020-12-10       West  L.A. Lakers
# 19395   1610612747          0     12020    2020-12-21       West  L.A. Lakers
# 12695   1610612747          0     22020    2021-10-02       West  L.A. Lakers
# 12463   1610612747          0     12021    2021-10-18       West  L.A. Lakers
# 1270    1610612747          0     22021    2022-09-29       West  L.A. Lakers
# 1004    1610612747          0     12022    2022-10-17       West  L.A. Lakers
# 12      1610612747          0     22022    2022-12-22       West  L.A. Lakers
#
#          G   W   L  W_PCT HOME_RECORD ROAD_RECORD  RETURNTOPLAY  SEASON_RANK  \
# 92900   82  50  32  0.610       31-10       19-22           NaN          5.0
# 92579    0   0   0  0.000         0-0         0-0           NaN          1.0
# 87676   82  56  26  0.683        34-7       22-19           NaN          4.0
# 87364    0   0   0  0.000         0-0         0-0           NaN          1.0
# 82240   82  34  48  0.415       22-19       12-29           NaN         21.0
# 81902    8   6   2  0.750         6-2         0-0           NaN          3.0
# 76834   82  45  37  0.549       27-14       18-23           NaN         10.0
# 76446    8   4   4  0.500         4-3         0-1           NaN         14.0
# 71346   82  42  40  0.512       25-16       17-24           NaN         12.0
# 70991    6   2   4  0.333         2-4         0-0           NaN         24.0
# 65864   82  57  25  0.695       30-11       27-14           NaN          3.0
# 65521    8   6   2  0.750         6-2         0-0           NaN          4.0
# 60449   82  65  17  0.793        36-5       29-12           NaN          2.0
# 60060    8   6   2  0.750         6-2         0-0           NaN          2.0
# 54944   82  57  25  0.695        34-7       23-18           NaN          3.0
# 54607    8   4   4  0.500         4-2         0-2           NaN         10.0
# 48361   82  57  25  0.695       30-11       27-14           NaN          4.0
# 48236    2   0   2  0.000         0-1         0-1           NaN         22.0
# 43951   66  41  25  0.621        26-7       15-18           NaN          6.0
# 43588    8   0   8  0.000         0-7         0-1           NaN         30.0
# 38481   82  45  37  0.549       29-12       16-25           NaN         11.0
# 38123    8   4   4  0.500         4-3         0-1           NaN         14.0
# 121255  82  27  55  0.329       14-27       13-28           NaN         25.0
# 120891   8   3   5  0.375         3-5         0-0           NaN         23.0
# 115810  82  21  61  0.256       12-29        9-32           NaN         27.0
# 115433   8   3   5  0.375         3-5         0-0           NaN         21.0
# 110336  82  17  65  0.207       12-29        5-36           NaN         29.0
# 109975   8   2   6  0.250         2-6         0-0           NaN         28.0
# 104875  82  26  56  0.317       17-24        9-32           NaN         28.0
# 104619   6   2   4  0.333         1-4         1-0           NaN         25.0
# 99427   82  35  47  0.427       20-21       15-26           NaN         21.0
# 99154    6   3   3  0.500         2-3         1-0           NaN         14.0
# 93921   82  37  45  0.451       22-19       15-26           NaN         20.0
# 24168    3   2   1  0.667         1-1         1-0           NaN          3.0
# 22154   71  52  19  0.732       25-10        27-9           NaN          3.0
# 19395    4   4   0  1.000         2-0         2-0           NaN          1.0
# 12695   72  42  30  0.583       21-15       21-15           NaN          8.0
# 12463    6   0   6  0.000         0-3         0-3           NaN         28.0
# 1270    82  33  49  0.402       21-20       12-29           NaN         23.0
# 1004     6   1   5  0.167         0-4         1-1           NaN         27.0
# 12      31  13  18  0.419         8-7        5-11           NaN         23.0
#
#        SEASON_FLAG  YEAR
# 92900            2  2002
# 92579            1  2003
# 87676            2  2003
# 87364            1  2004
# 82240            2  2004
# 81902            1  2005
# 76834            2  2005
# 76446            1  2006
# 71346            2  2006
# 70991            1  2007
# 65864            2  2007
# 65521            1  2008
# 60449            2  2008
# 60060            1  2009
# 54944            2  2009
# 54607            1  2010
# 48361            2  2010
# 48236            1  2011
# 43951            2  2011
# 43588            1  2012
# 38481            2  2012
# 38123            1  2013
# 121255           2  2013
# 120891           1  2014
# 115810           2  2014
# 115433           1  2015
# 110336           2  2015
# 109975           1  2016
# 104875           2  2016
# 104619           1  2017
# 99427            2  2017
# 99154            1  2018
# 93921            2  2018
# 24168            1  2019
# 22154            2  2019
# 19395            1  2020
# 12695            2  2020
# 12463            1  2021
# 1270             2  2021
# 1004             1  2022
# 12               2  2022

# %%
plt.figure(figsize=(10, 4))
sns.lineplot(detroit_season_ranking.iloc[-20:], x='YEAR', y='SEASON_RANK', hue='SEASON_FLAG')

plt.title(f'{team}의 시즌 별 순위')
plt.xlabel('시즌')
plt.ylabel('순위')
plt.ylim((30, 1))
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 전체 순위 변동

# %%
regular_final_ranking = final_ranking[final_ranking['SEASON_FLAG'] == '2'].sort_values('STANDINGSDATE')

regular_final_ranking
# Out:
#            TEAM_ID  LEAGUE_ID SEASON_ID STANDINGSDATE CONFERENCE        TEAM  \
# 181506  1610612764          0     22002    2003-10-04       East  Washington
# 181511  1610612739          0     22002    2003-10-04       East   Cleveland
# 181510  1610612761          0     22002    2003-10-04       East     Toronto
# 181509  1610612748          0     22002    2003-10-04       East       Miami
# 181508  1610612741          0     22002    2003-10-04       East     Chicago
# ...            ...        ...       ...           ...        ...         ...
# 4286    1610612753          0     22022    2022-12-22       East     Orlando
# 4287    1610612764          0     22022    2022-12-22       East  Washington
# 4289    1610612765          0     22022    2022-12-22       East     Detroit
# 4275    1610612749          0     22022    2022-12-22       East   Milwaukee
# 0       1610612743          0     22022    2022-12-22       West      Denver
#
#          G   W   L  W_PCT HOME_RECORD ROAD_RECORD  RETURNTOPLAY  SEASON_RANK  \
# 181506  82  37  45  0.451       23-18       14-27           NaN         20.0
# 181511  82  17  65  0.207       14-27        3-38           NaN         28.0
# 181510  82  24  58  0.293       15-26        9-32           NaN         27.0
# 181509  82  25  57  0.305       16-25        9-32           NaN         26.0
# 181508  82  30  52  0.366       27-14        3-38           NaN         23.0
# ...     ..  ..  ..    ...         ...         ...           ...          ...
# 4286    33  12  21  0.364         8-9        4-12           NaN         25.0
# 4287    33  12  21  0.364         8-7        4-14           NaN         25.0
# 4289    34   8  26  0.235        4-12        4-14           NaN         30.0
# 4275    31  22   9  0.710        14-3         8-6           NaN          1.0
# 0       30  19  11  0.633        10-3         9-8           NaN          4.0
#
#        SEASON_FLAG  YEAR
# 181506           2  2002
# 181511           2  2002
# 181510           2  2002
# 181509           2  2002
# 181508           2  2002
# ...            ...   ...
# 4286             2  2022
# 4287             2  2022
# 4289             2  2022
# 4275             2  2022
# 0                2  2022
#
# [628 rows x 16 columns]

# %%
regular_final_ranking = final_ranking[final_ranking['SEASON_FLAG'] == '2'].sort_values('STANDINGSDATE')

plt.figure(figsize=(10, 4))
sns.lineplot(regular_final_ranking, x='YEAR', y='SEASON_RANK', hue='TEAM')

plt.title('Detroit의 시즌 별 순위')
plt.xlabel('시즌')
plt.ylabel('순위')
plt.ylim((30, 1))
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
regular_final_ranking.to_csv(DATA_DIR / 'temp_ranking.csv', index=False)
